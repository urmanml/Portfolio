# %% [markdown]
# ## Recurrent neural network method

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
df= pd.read_csv("E:/Python WD/time_series/data/Work Data - Sheet1.csv")

# %% [markdown]
# #### Preparing data for time series analysis

# %%
#define columns
df.columns
time_series_index= 'obs'
forecast_variable= 'FTCORTCS'
#these are additional variables for multivariate forecasting
additional_variables= ['EEA', 'UYCD', 'FNNF', 'FYPTY', 'JGDPMTPR', 'UFCORPTS',
       'UFSNPEPS', 'YPPROPADJNF', 'ZB']

frequency= 'Q'

#number of out of time samples held for test set. Model output will be compared with this for out  of time validation
#note that validation set is separate and it will be carved out of the supervised train set through random sampling
n_test= 8

# number of input samples in test train predict pair in lstm
train_length= 8

# number of output samples in test train predict pair in lstm
output_length= 2

forecast_points= 40

# %% [markdown]
# #### Prepare data

# %%
#set datetime index column
df[time_series_index]= pd.to_datetime(df[time_series_index])
df= df.set_index(time_series_index)

#bring forecast variable column at index 0 
df= pd.concat([df[[forecast_variable]],df.drop(columns=forecast_variable)], axis=1)


df_complete= df
df= df[df.index<='2019Q3']

# %% [markdown]
# #### Visualizing the data

# %%
df[[forecast_variable]].plot()
plt.title('plot of actual data')

df[[forecast_variable]].rolling(4).mean().plot()
plt.title('plot of 1 year rolling mean')
df[[forecast_variable]].rolling(12).mean().plot()
plt.title('plot of 12 year rolling mean')
# Out:
# Text(0.5, 1.0, 'plot of 12 year rolling mean')

# %% [markdown]
# #### Train test split

# %%
n_test= n_test # 8 quarters in test data<-- make it 0 to forecast
n_train= df.shape[0]-n_test

train_df= df[:n_train]
test_df= df[-n_test:]

# %% [markdown]
# #### Feature Standardization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(train_df)
train_df= scaler.transform(train_df)
#test_df= scaler.transform(test_df)
scaler.inverse_transform(train_df)
#scaler.scale_[-1]


output_length= output_length
#train length: taking train
#train_length= round(1.5*output_length)

# %% [markdown]
# #### Transform data for neural network training

# %%
def data_transform(train_df, train_length, output_length):
    samples=list()
    #length = 200
    # step over the 5,000 in jumps of 200
    i=0
    for i in range(0,train_df.shape[0]+1-train_length-output_length):
        # grab from i to i + 200
        sample = train_df[i:i+train_length+output_length]
        samples.append(sample)
    print(len(samples))
    #np.array(samples).reshape(5,4)
    A= np.dstack(samples)
    A.shape
    A_new= np.moveaxis(A, -1, 0)
    A_new.shape
    #it creates n+1- (length+output_length) number of samples
    samples[0]
    X, Y= A_new[:,:train_length,:], A_new[:,train_length:,0]
    return X, Y

X, Y = data_transform(train_df, train_length ,output_length)
#A_test= data_transform(test_df)
# Out:
# 102

# %% [markdown]
# #### Prepare train and validation set

# %%
import tensorflow as tf
from tensorflow import keras

valid_split= 0.20
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size= valid_split, random_state=1234 )
Y.shape
X.shape

X_train.shape
#(74,12,10)
X_valid.shape
#(18,12,10)
Y_train.shape
#(74,8)


np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# #### Define the model

# %%
##lstm
model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, activation='relu', return_sequences=True, input_shape=[X_train.shape[1], X_train.shape[2]]),
    keras.layers.Dropout(.2),
    #keras.layers.SimpleRNN(20, activation='relu', return_sequences=True),
    keras.layers.SimpleRNN(10),
    
    #keras.layers.TimeDistributed(keras.layers.Dense(10))
    keras.layers.Dense(output_length)

])

# %% [markdown]
# #### Compile the model

# %%
model.compile(loss="mae", optimizer="adam")

# %% [markdown]
# #### Fit the model

# %%
n_epochs= 250
history = model.fit(X_train, Y_train, epochs=n_epochs,
                    validation_data=(X_valid, Y_valid))
model.input_shape
model.output_shape

model.summary()
import matplotlib.pyplot as plt
import seaborn as sns
sns.lineplot(x= range(0, n_epochs), y= history.history['val_loss'], label='val_loss')
sns.lineplot(x= range(0, n_epochs), y= history.history['loss'], label='loss')
# Out:
# Train on 81 samples, validate on 21 samples
# Epoch 1/250
# 81/81 [==============================] - 2s 31ms/sample - loss: 0.9652 - val_loss: 1.0006
# Epoch 2/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.8201 - val_loss: 0.8601
# Epoch 3/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.6916 - val_loss: 0.6935
# Epoch 4/250
# 81/81 [==============================] - 0s 459us/sample - loss: 0.5608 - val_loss: 0.5159
# Epoch 5/250
# 81/81 [==============================] - 0s 459us/sample - loss: 0.4225 - val_loss: 0.3694
# Epoch 6/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.3814 - val_loss: 0.2942
# Epoch 7/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.3384 - val_loss: 0.2570
# Epoch 8/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2856 - val_loss: 0.2307
# Epoch 9/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2991 - val_loss: 0.2115
# Epoch 10/250
# 81/81 [==============================] - 0s 574us/sample - loss: 0.2931 - val_loss: 0.1914
# Epoch 11/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.2809 - val_loss: 0.1738
# Epoch 12/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2408 - val_loss: 0.1592
# Epoch 13/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2363 - val_loss: 0.1513
# Epoch 14/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2320 - val_loss: 0.1457
# Epoch 15/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2247 - val_loss: 0.1430
# Epoch 16/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2427 - val_loss: 0.1433
# Epoch 17/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2087 - val_loss: 0.1438
# Epoch 18/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2113 - val_loss: 0.1453
# Epoch 19/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2104 - val_loss: 0.1458
# Epoch 20/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2040 - val_loss: 0.1457
# Epoch 21/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1963 - val_loss: 0.1432
# Epoch 22/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.2005 - val_loss: 0.1395
# Epoch 23/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1931 - val_loss: 0.1378
# Epoch 24/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1896 - val_loss: 0.1370
# Epoch 25/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1724 - val_loss: 0.1365
# Epoch 26/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1771 - val_loss: 0.1363
# Epoch 27/250
# 81/81 [==============================] - 0s 569us/sample - loss: 0.1876 - val_loss: 0.1367
# Epoch 28/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1819 - val_loss: 0.1366
# Epoch 29/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1651 - val_loss: 0.1360
# Epoch 30/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1685 - val_loss: 0.1345
# Epoch 31/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1795 - val_loss: 0.1334
# Epoch 32/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1777 - val_loss: 0.1318
# Epoch 33/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1686 - val_loss: 0.1311
# Epoch 34/250
# 81/81 [==============================] - 0s 481us/sample - loss: 0.1628 - val_loss: 0.1312
# Epoch 35/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1720 - val_loss: 0.1315
# Epoch 36/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1563 - val_loss: 0.1318
# Epoch 37/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1683 - val_loss: 0.1321
# Epoch 38/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1679 - val_loss: 0.1318
# Epoch 39/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1608 - val_loss: 0.1312
# Epoch 40/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1791 - val_loss: 0.1307
# Epoch 41/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1645 - val_loss: 0.1304
# Epoch 42/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1576 - val_loss: 0.1306
# Epoch 43/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1681 - val_loss: 0.1311
# Epoch 44/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1618 - val_loss: 0.1313
# Epoch 45/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1632 - val_loss: 0.1301
# Epoch 46/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1498 - val_loss: 0.1282
# Epoch 47/250
# 81/81 [==============================] - 0s 621us/sample - loss: 0.1602 - val_loss: 0.1258
# Epoch 48/250
# 81/81 [==============================] - 0s 457us/sample - loss: 0.1535 - val_loss: 0.1248
# Epoch 49/250
# 81/81 [==============================] - 0s 503us/sample - loss: 0.1617 - val_loss: 0.1239
# Epoch 50/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1597 - val_loss: 0.1236
# Epoch 51/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1430 - val_loss: 0.1232
# Epoch 52/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1508 - val_loss: 0.1228
# Epoch 53/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1521 - val_loss: 0.1224
# Epoch 54/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1460 - val_loss: 0.1225
# Epoch 55/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1523 - val_loss: 0.1231
# Epoch 56/250
# 81/81 [==============================] - 0s 447us/sample - loss: 0.1428 - val_loss: 0.1224
# Epoch 57/250
# 81/81 [==============================] - 0s 445us/sample - loss: 0.1430 - val_loss: 0.1208
# Epoch 58/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1423 - val_loss: 0.1202
# Epoch 59/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1481 - val_loss: 0.1199
# Epoch 60/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1447 - val_loss: 0.1200
# Epoch 61/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1432 - val_loss: 0.1204
# Epoch 62/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1470 - val_loss: 0.1204
# Epoch 63/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1353 - val_loss: 0.1198
# Epoch 64/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1595 - val_loss: 0.1191
# Epoch 65/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1386 - val_loss: 0.1188
# Epoch 66/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1456 - val_loss: 0.1183
# Epoch 67/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1398 - val_loss: 0.1178
# Epoch 68/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1406 - val_loss: 0.1170
# Epoch 69/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1445 - val_loss: 0.1166
# Epoch 70/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1303 - val_loss: 0.1161
# Epoch 71/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1443 - val_loss: 0.1169
# Epoch 72/250
# 81/81 [==============================] - 0s 473us/sample - loss: 0.1366 - val_loss: 0.1182
# Epoch 73/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1464 - val_loss: 0.1189
# Epoch 74/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1362 - val_loss: 0.1188
# Epoch 75/250
# 81/81 [==============================] - 0s 397us/sample - loss: 0.1388 - val_loss: 0.1188
# Epoch 76/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1431 - val_loss: 0.1189
# Epoch 77/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1352 - val_loss: 0.1187
# Epoch 78/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1361 - val_loss: 0.1179
# Epoch 79/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1406 - val_loss: 0.1172
# Epoch 80/250
# 81/81 [==============================] - 0s 489us/sample - loss: 0.1270 - val_loss: 0.1163
# Epoch 81/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1317 - val_loss: 0.1158
# Epoch 82/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1289 - val_loss: 0.1156
# Epoch 83/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1255 - val_loss: 0.1153
# Epoch 84/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1300 - val_loss: 0.1155
# Epoch 85/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1301 - val_loss: 0.1161
# Epoch 86/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1307 - val_loss: 0.1161
# Epoch 87/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1304 - val_loss: 0.1155
# Epoch 88/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1299 - val_loss: 0.1149
# Epoch 89/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1209 - val_loss: 0.1143
# Epoch 90/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1274 - val_loss: 0.1140
# Epoch 91/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1306 - val_loss: 0.1135
# Epoch 92/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1248 - val_loss: 0.1121
# Epoch 93/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1155 - val_loss: 0.1115
# Epoch 94/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1239 - val_loss: 0.1118
# Epoch 95/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1275 - val_loss: 0.1117
# Epoch 96/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1275 - val_loss: 0.1117
# Epoch 97/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1285 - val_loss: 0.1112
# Epoch 98/250
# 81/81 [==============================] - 0s 520us/sample - loss: 0.1270 - val_loss: 0.1109
# Epoch 99/250
# 81/81 [==============================] - 0s 497us/sample - loss: 0.1232 - val_loss: 0.1103
# Epoch 100/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1231 - val_loss: 0.1097
# Epoch 101/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.1242 - val_loss: 0.1092
# Epoch 102/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1172 - val_loss: 0.1083
# Epoch 103/250
# 81/81 [==============================] - 0s 496us/sample - loss: 0.1181 - val_loss: 0.1082
# Epoch 104/250
# 81/81 [==============================] - 0s 552us/sample - loss: 0.1211 - val_loss: 0.1085
# Epoch 105/250
# 81/81 [==============================] - 0s 482us/sample - loss: 0.1234 - val_loss: 0.1074
# Epoch 106/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1193 - val_loss: 0.1065
# Epoch 107/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1219 - val_loss: 0.1061
# Epoch 108/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1141 - val_loss: 0.1054
# Epoch 109/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1214 - val_loss: 0.1052
# Epoch 110/250
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1185 - val_loss: 0.1039
# Epoch 111/250
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1134 - val_loss: 0.1030
# Epoch 112/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1147 - val_loss: 0.1029
# Epoch 113/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1203 - val_loss: 0.1032
# Epoch 114/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1157 - val_loss: 0.1023
# Epoch 115/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1126 - val_loss: 0.1024
# Epoch 116/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1149 - val_loss: 0.1028
# Epoch 117/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1169 - val_loss: 0.1020
# Epoch 118/250
# 81/81 [==============================] - 0s 491us/sample - loss: 0.1129 - val_loss: 0.0999
# Epoch 119/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1156 - val_loss: 0.0980
# Epoch 120/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1170 - val_loss: 0.0965
# Epoch 121/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1121 - val_loss: 0.0949
# Epoch 122/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1098 - val_loss: 0.0937
# Epoch 123/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1101 - val_loss: 0.0933
# Epoch 124/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1093 - val_loss: 0.0927
# Epoch 125/250
# 81/81 [==============================] - 0s 448us/sample - loss: 0.1086 - val_loss: 0.0924
# Epoch 126/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1119 - val_loss: 0.0918
# Epoch 127/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1165 - val_loss: 0.0918
# Epoch 128/250
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1112 - val_loss: 0.0920
# Epoch 129/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1104 - val_loss: 0.0917
# Epoch 130/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1103 - val_loss: 0.0904
# Epoch 131/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1033 - val_loss: 0.0892
# Epoch 132/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1063 - val_loss: 0.0884
# Epoch 133/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1115 - val_loss: 0.0881
# Epoch 134/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1106 - val_loss: 0.0883
# Epoch 135/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1100 - val_loss: 0.0887
# Epoch 136/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1045 - val_loss: 0.0905
# Epoch 137/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1118 - val_loss: 0.0909
# Epoch 138/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1036 - val_loss: 0.0885
# Epoch 139/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1049 - val_loss: 0.0866
# Epoch 140/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1047 - val_loss: 0.0852
# Epoch 141/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1049 - val_loss: 0.0850
# Epoch 142/250
# 81/81 [==============================] - 0s 483us/sample - loss: 0.1006 - val_loss: 0.0847
# Epoch 143/250
# 81/81 [==============================] - 0s 592us/sample - loss: 0.1023 - val_loss: 0.0837
# Epoch 144/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1004 - val_loss: 0.0845
# Epoch 145/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0973 - val_loss: 0.0841
# Epoch 146/250
# 81/81 [==============================] - 0s 605us/sample - loss: 0.1002 - val_loss: 0.0830
# Epoch 147/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0987 - val_loss: 0.0827
# Epoch 148/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1026 - val_loss: 0.0816
# Epoch 149/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0955 - val_loss: 0.0814
# Epoch 150/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1018 - val_loss: 0.0822
# Epoch 151/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0929 - val_loss: 0.0844
# Epoch 152/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0986 - val_loss: 0.0888
# Epoch 153/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1023 - val_loss: 0.0881
# Epoch 154/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1055 - val_loss: 0.0821
# Epoch 155/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0952 - val_loss: 0.0814
# Epoch 156/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0936 - val_loss: 0.0830
# Epoch 157/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0999 - val_loss: 0.0840
# Epoch 158/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0926 - val_loss: 0.0820
# Epoch 159/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0935 - val_loss: 0.0822
# Epoch 160/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0929 - val_loss: 0.0818
# Epoch 161/250
# 81/81 [==============================] - 0s 562us/sample - loss: 0.0887 - val_loss: 0.0807
# Epoch 162/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0907 - val_loss: 0.0798
# Epoch 163/250
# 81/81 [==============================] - 0s 554us/sample - loss: 0.0956 - val_loss: 0.0799
# Epoch 164/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0949 - val_loss: 0.0805
# Epoch 165/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0995 - val_loss: 0.0827
# Epoch 166/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0862 - val_loss: 0.0867
# Epoch 167/250
# 81/81 [==============================] - 0s 497us/sample - loss: 0.0939 - val_loss: 0.0882
# Epoch 168/250
# 81/81 [==============================] - 0s 469us/sample - loss: 0.0926 - val_loss: 0.0831
# Epoch 169/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.1039 - val_loss: 0.0814
# Epoch 170/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0929 - val_loss: 0.0818
# Epoch 171/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0931 - val_loss: 0.0834
# Epoch 172/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0945 - val_loss: 0.0853
# Epoch 173/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0985 - val_loss: 0.0835
# Epoch 174/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0897 - val_loss: 0.0826
# Epoch 175/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0976 - val_loss: 0.0812
# Epoch 176/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0937 - val_loss: 0.0822
# Epoch 177/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0853 - val_loss: 0.0813
# Epoch 178/250
# 81/81 [==============================] - 0s 691us/sample - loss: 0.0885 - val_loss: 0.0796
# Epoch 179/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0863 - val_loss: 0.0791
# Epoch 180/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0938 - val_loss: 0.0794
# Epoch 181/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0929 - val_loss: 0.0800
# Epoch 182/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0913 - val_loss: 0.0826
# Epoch 183/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0868 - val_loss: 0.0831
# Epoch 184/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0892 - val_loss: 0.0825
# Epoch 185/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0866 - val_loss: 0.0823
# Epoch 186/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0912 - val_loss: 0.0817
# Epoch 187/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0899 - val_loss: 0.0816
# Epoch 188/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0891 - val_loss: 0.0819
# Epoch 189/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0880 - val_loss: 0.0800
# Epoch 190/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0933 - val_loss: 0.0787
# Epoch 191/250
# 81/81 [==============================] - 0s 558us/sample - loss: 0.0923 - val_loss: 0.0777
# Epoch 192/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0820 - val_loss: 0.0781
# Epoch 193/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0890 - val_loss: 0.0790
# Epoch 194/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0932 - val_loss: 0.0797
# Epoch 195/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0831 - val_loss: 0.0809
# Epoch 196/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0871 - val_loss: 0.0811
# Epoch 197/250
# 81/81 [==============================] - 0s 592us/sample - loss: 0.0853 - val_loss: 0.0806
# Epoch 198/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0895 - val_loss: 0.0785
# Epoch 199/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0868 - val_loss: 0.0772
# Epoch 200/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0838 - val_loss: 0.0775
# Epoch 201/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0829 - val_loss: 0.0808
# Epoch 202/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0971 - val_loss: 0.0789
# Epoch 203/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0863 - val_loss: 0.0755
# Epoch 204/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0847 - val_loss: 0.0744
# Epoch 205/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0833 - val_loss: 0.0740
# Epoch 206/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0834 - val_loss: 0.0743
# Epoch 207/250
# 81/81 [==============================] - 0s 383us/sample - loss: 0.0887 - val_loss: 0.0760
# Epoch 208/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0797 - val_loss: 0.0772
# Epoch 209/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0806 - val_loss: 0.0737
# Epoch 210/250
# 81/81 [==============================] - 0s 449us/sample - loss: 0.0777 - val_loss: 0.0723
# Epoch 211/250
# 81/81 [==============================] - 0s 461us/sample - loss: 0.0847 - val_loss: 0.0732
# Epoch 212/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0774 - val_loss: 0.0739
# Epoch 213/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0755 - val_loss: 0.0738
# Epoch 214/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0808 - val_loss: 0.0716
# Epoch 215/250
# 81/81 [==============================] - 0s 550us/sample - loss: 0.0730 - val_loss: 0.0691
# Epoch 216/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0817 - val_loss: 0.0682
# Epoch 217/250
# 81/81 [==============================] - 0s 561us/sample - loss: 0.0767 - val_loss: 0.0683
# Epoch 218/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0727 - val_loss: 0.0719
# Epoch 219/250
# 81/81 [==============================] - 0s 510us/sample - loss: 0.0764 - val_loss: 0.0691
# Epoch 220/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0706 - val_loss: 0.0690
# Epoch 221/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0707 - val_loss: 0.0674
# Epoch 222/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0786 - val_loss: 0.0692
# Epoch 223/250
# 81/81 [==============================] - 0s 790us/sample - loss: 0.0715 - val_loss: 0.0717
# Epoch 224/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0784 - val_loss: 0.0652
# Epoch 225/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0704 - val_loss: 0.0665
# Epoch 226/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0745 - val_loss: 0.0659
# Epoch 227/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0689 - val_loss: 0.0635
# Epoch 228/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0669 - val_loss: 0.0638
# Epoch 229/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0741 - val_loss: 0.0641
# Epoch 230/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0754 - val_loss: 0.0589
# Epoch 231/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0658 - val_loss: 0.0560
# Epoch 232/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0677 - val_loss: 0.0556
# Epoch 233/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0674 - val_loss: 0.0559
# Epoch 234/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0689 - val_loss: 0.0570
# Epoch 235/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0676 - val_loss: 0.0572
# Epoch 236/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0726 - val_loss: 0.0574
# Epoch 237/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0660 - val_loss: 0.0563
# Epoch 238/250
# 81/81 [==============================] - 0s 507us/sample - loss: 0.0660 - val_loss: 0.0548
# Epoch 239/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0603 - val_loss: 0.0546
# Epoch 240/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0660 - val_loss: 0.0545
# Epoch 241/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0659 - val_loss: 0.0533
# Epoch 242/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0677 - val_loss: 0.0530
# Epoch 243/250
# 81/81 [==============================] - 0s 593us/sample - loss: 0.0701 - val_loss: 0.0528
# Epoch 244/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0642 - val_loss: 0.0527
# Epoch 245/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0683 - val_loss: 0.0552
# Epoch 246/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0636 - val_loss: 0.0525
# Epoch 247/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0571 - val_loss: 0.0514
# Epoch 248/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0572 - val_loss: 0.0517
# Epoch 249/250
# 81/81 [==============================] - 0s 494us/sample - loss: 0.0637 - val_loss: 0.0515
# Epoch 250/250
# 81/81 [==============================] - 0s 395us/sample - loss: 0.0713 - val_loss: 0.0542
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_26 (SimpleRNN)    (None, 8, 20)             620
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 8, 20)             0
# _________________________________________________________________
# simple_rnn_27 (SimpleRNN)    (None, 10)                310
# _________________________________________________________________
# dense_10 (Dense)             (None, 2)                 22
# =================================================================
# Total params: 952
# Trainable params: 952
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### preprocess the whole data

# %%
#i: index location of last point in training
#forecast_iterations: number of iterations to be the forecast loop will run. 
#Forecast points= output_length* forecast_iterations

def forecast(df_complete, i, forecast_iterations ):

    
    #scale the dataframe 
    df_complete_updated = df_complete*scaler.scale_
    #iterate till we have all required number of forecast points

    for iter in range(0,forecast_iterations):
        # for each iteration
        #1  Extract the model input
        temp= df_complete_updated[(df_complete_updated.index<= df_complete_updated.index[i]).astype(bool) & (df_complete_updated.index> df_complete_updated.index[i-train_length]).astype(bool)]
        #2  turn datframe into array and Shape it as required bythe model
        model_input= temp.values.reshape(1,train_length,df_complete.shape[1])

        #validate that correct transformation has been done

        model_input[0,:,0] # shows predictor variable latest 8 values in a scaled format
        #3) Pass it to the model and forecast the output
        model_output= model.predict(model_input)
        
        
        #4) update the values in the dataframe with the forecasted values
        
        df_complete_updated.loc[
                    df_complete_updated.index[i+1:i+1+output_length]

            ,forecast_variable]= model_output
        
        #5) Update the index- index location of the last observation of model input array
        i= i+output_length
    
    #inverse transform scaling to obtain original values. This is done at once after all iterations have been done.
    df_complete_updated= df_complete_updated/ scaler.scale_
    
    return df_complete_updated

# %% [markdown]
# #### Prepare data to validate on the test set

# %%
i= 110
forecast_iterations =int(n_test/output_length) # 8/4
import tensorflow as tf

df_complete_updated_test= forecast(df_complete, i, forecast_iterations)

# %% [markdown]
# #### Prepare data to forecast on the complete set

# %%
i= 118
forecast_iterations =int(forecast_points/output_length)# 40/4

df_complete_updated_forecast= forecast(df_complete, i, forecast_iterations)

# %% [markdown]
# #### Combine all three data for plotting purpose

# %%
import numpy as np

plot_data= pd.concat([
           df_complete_updated_test[forecast_variable],
           df_complete_updated_forecast[forecast_variable],
            df_complete[forecast_variable]], axis=1)
plot_data.columns= ['test','predicted', 'actual']
type(plot_data.predicted[-1])
plot_data.loc[plot_data.index<='2017Q3','test']=np.nan
plot_data.loc[plot_data.index>'2019Q3','test']=np.nan

plot_data.loc[plot_data.index<='2019Q3','predicted']=np.nan

# %% [markdown]
# #### Comparison of accuracy on test set

# %%
plot_data[['actual', 'test']][111:119].plot()
plt.title('comparison of last 2 years output with actual')
# Out:
# Text(0.5, 1.0, 'comparison of last 2 years output with actual')

# %% [markdown]
# #### Computing performance and storing it in a file

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np 
from math import sqrt
print("MAE")
mae= mean_absolute_error(plot_data[111:119].actual.values, plot_data[111:119].test.values)
print(mae)
print("RSME")
rmse= sqrt(mean_squared_error(plot_data[111:119].actual.values, plot_data[111:119].test.values))
print(rmse)
# Out:
# MAE
# 283.5185612835568
# RSME
# 376.71459965847026

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from numpy import math
metrics= pd.read_csv('E:/Python WD/time_series/data/metrics.csv', index_col='Unnamed: 0')
metrics.loc['mean absolute error', 'RNN']= mae
print('mean absolute error: '+str(mae))
metrics.loc['mean squared error', 'RNN']= rmse
print('root mean squared error: '+str(rmse))

metrics.to_csv('E:/Python WD/time_series/data/metrics.csv')
#metrics
# Out:
# mean absolute error: 283.5185612835568
# root mean squared error: 376.71459965847026

# %% [markdown]
# #### Forecast for next 10 years

# %%
plot_data[['actual','predicted']].plot()
plt.title('forecast of next 10 years data')
# Out:
# Text(0.5, 1.0, 'forecast of next 10 years data')

# %% [markdown]
# #### Storing the forecasts for next 10 years

# %%
predictions= pd.read_csv('E:/Python WD/time_series/data/predictions.csv', index_col= 'Unnamed: 0')
#obtain predictions for next 10 years
temp= plot_data[plot_data.index>'2019Q3'][['predicted']][0:40]
predictions.loc[:,'RNN']=temp.values
predictions.to_csv('E:/Python WD/time_series/data/predictions.csv')
