# %% [markdown]
# ## LSTM method

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
df= pd.read_csv("E:/Python WD/time_series/data/Work Data - Sheet1.csv")

# %% [markdown]
# #### Preparing data for time series analysis

# %%
#define columns
df.columns
time_series_index= 'obs'
forecast_variable= 'FTCORTCS'
#these are additional variables for multivariate forecasting
additional_variables= ['EEA', 'UYCD', 'FNNF', 'FYPTY', 'JGDPMTPR', 'UFCORPTS',
       'UFSNPEPS', 'YPPROPADJNF', 'ZB']

frequency= 'Q'

#number of out of time samples held for test set. Model output will be compared with this for out  of time validation
#note that validation set is separate and it will be carved out of the supervised train set through random sampling
n_test= 8

# number of input samples in test train predict pair in lstm
train_length= 8

# number of output samples in test train predict pair in lstm
output_length= 2

forecast_points= 40

# %% [markdown]
# #### Prepare data

# %%
#set datetime index column
df[time_series_index]= pd.to_datetime(df[time_series_index])
df= df.set_index(time_series_index)

#bring forecast variable column at index 0 
df= pd.concat([df[[forecast_variable]],df.drop(columns=forecast_variable)], axis=1)


df_complete= df
df= df[df.index<='2019Q3']

# %% [markdown]
# #### Visualizing the data

# %%
df[[forecast_variable]].plot()
plt.title('plot of actual data')

df[[forecast_variable]].rolling(4).mean().plot()
plt.title('plot of 1 year rolling mean')
df[[forecast_variable]].rolling(12).mean().plot()
plt.title('plot of 12 year rolling mean')
# Out:
# Text(0.5, 1.0, 'plot of 12 year rolling mean')

# %% [markdown]
# #### Train test split

# %%
n_test= n_test # 8 quarters in test data<-- make it 0 to forecast
n_train= df.shape[0]-n_test

train_df= df[:n_train]
test_df= df[-n_test:]

# %% [markdown]
# #### Feature Standardization

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(train_df)
train_df= scaler.transform(train_df)
#test_df= scaler.transform(test_df)
scaler.inverse_transform(train_df)
#scaler.scale_[-1]


output_length= output_length
#train length: taking train
#train_length= round(1.5*output_length)

# %% [markdown]
# #### Transform data for neural network training

# %%
def data_transform(train_df, train_length, output_length):
    samples=list()
    #length = 200
    # step over the 5,000 in jumps of 200
    i=0
    for i in range(0,train_df.shape[0]+1-train_length-output_length):
        # grab from i to i + 200
        sample = train_df[i:i+train_length+output_length]
        samples.append(sample)
    print(len(samples))
    #np.array(samples).reshape(5,4)
    A= np.dstack(samples)
    A.shape
    A_new= np.moveaxis(A, -1, 0)
    A_new.shape
    #it creates n+1- (length+output_length) number of samples
    samples[0]
    X, Y= A_new[:,:train_length,:], A_new[:,train_length:,0]
    return X, Y

X, Y = data_transform(train_df, train_length ,output_length)
#A_test= data_transform(test_df)
# Out:
# 102

# %% [markdown]
# #### Prepare train and validation set

# %%
import tensorflow as tf
from tensorflow import keras

valid_split= 0.20
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(X, Y, test_size= valid_split, random_state=1234 )
Y.shape
X.shape

X_train.shape
#(74,12,10)
X_valid.shape
#(18,12,10)
Y_train.shape
#(74,8)


np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# #### Define the model

# %%
##lstm
model = keras.models.Sequential([
    keras.layers.LSTM(20, activation='relu', return_sequences=True, input_shape=[X_train.shape[1], X_train.shape[2]]),
    keras.layers.LSTM(20, activation='relu', return_sequences=True),
    keras.layers.LSTM(10),
    #keras.layers.TimeDistributed(keras.layers.Dense(10))
    keras.layers.Dense(output_length)

])

# %% [markdown]
# #### Compile the model

# %%
model.compile(loss="mae", optimizer="adam")

# %% [markdown]
# #### Fit the model

# %%
n_epochs= 200
history = model.fit(X_train, Y_train, epochs=n_epochs,
                    validation_data=(X_valid, Y_valid))
model.input_shape
model.output_shape

model.summary()
import matplotlib.pyplot as plt
import seaborn as sns
sns.lineplot(x= range(0, n_epochs), y= history.history['val_loss'])
sns.lineplot(x= range(0, n_epochs), y= history.history['loss'])
# Out:
# Train on 81 samples, validate on 21 samples
# Epoch 1/200
# 81/81 [==============================] - 10s 126ms/sample - loss: 0.3731 - val_loss: 0.3958
# Epoch 2/200
# 81/81 [==============================] - 0s 592us/sample - loss: 0.3481 - val_loss: 0.3699
# Epoch 3/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.3244 - val_loss: 0.3444
# Epoch 4/200
# 81/81 [==============================] - 0s 592us/sample - loss: 0.3020 - val_loss: 0.3226
# Epoch 5/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.2830 - val_loss: 0.2998
# Epoch 6/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.2653 - val_loss: 0.2744
# Epoch 7/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.2441 - val_loss: 0.2471
# Epoch 8/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.2236 - val_loss: 0.2162
# Epoch 9/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.2006 - val_loss: 0.1882
# Epoch 10/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1786 - val_loss: 0.1684
# Epoch 11/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1582 - val_loss: 0.1382
# Epoch 12/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1378 - val_loss: 0.1190
# Epoch 13/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1344 - val_loss: 0.1193
# Epoch 14/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1404 - val_loss: 0.1203
# Epoch 15/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1391 - val_loss: 0.1218
# Epoch 16/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1340 - val_loss: 0.1211
# Epoch 17/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1276 - val_loss: 0.1253
# Epoch 18/200
# 81/81 [==============================] - 0s 545us/sample - loss: 0.1278 - val_loss: 0.1296
# Epoch 19/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1270 - val_loss: 0.1303
# Epoch 20/200
# 81/81 [==============================] - 0s 673us/sample - loss: 0.1248 - val_loss: 0.1296
# Epoch 21/200
# 81/81 [==============================] - 0s 612us/sample - loss: 0.1241 - val_loss: 0.1278
# Epoch 22/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1234 - val_loss: 0.1263
# Epoch 23/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1243 - val_loss: 0.1277
# Epoch 24/200
# 81/81 [==============================] - 0s 742us/sample - loss: 0.1236 - val_loss: 0.1306
# Epoch 25/200
# 81/81 [==============================] - 0s 694us/sample - loss: 0.1226 - val_loss: 0.1321
# Epoch 26/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1224 - val_loss: 0.1321
# Epoch 27/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1221 - val_loss: 0.1304
# Epoch 28/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1220 - val_loss: 0.1289
# Epoch 29/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1216 - val_loss: 0.1272
# Epoch 30/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1215 - val_loss: 0.1272
# Epoch 31/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1218 - val_loss: 0.1286
# Epoch 32/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1214 - val_loss: 0.1277
# Epoch 33/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1213 - val_loss: 0.1263
# Epoch 34/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1209 - val_loss: 0.1265
# Epoch 35/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1208 - val_loss: 0.1270
# Epoch 36/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1207 - val_loss: 0.1276
# Epoch 37/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1207 - val_loss: 0.1276
# Epoch 38/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1204 - val_loss: 0.1280
# Epoch 39/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1205 - val_loss: 0.1289
# Epoch 40/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1205 - val_loss: 0.1284
# Epoch 41/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1205 - val_loss: 0.1272
# Epoch 42/200
# 81/81 [==============================] - 0s 764us/sample - loss: 0.1199 - val_loss: 0.1272
# Epoch 43/200
# 81/81 [==============================] - 0s 659us/sample - loss: 0.1197 - val_loss: 0.1262
# Epoch 44/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1198 - val_loss: 0.1245
# Epoch 45/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1198 - val_loss: 0.1226
# Epoch 46/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1201 - val_loss: 0.1238
# Epoch 47/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1190 - val_loss: 0.1274
# Epoch 48/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1195 - val_loss: 0.1304
# Epoch 49/200
# 81/81 [==============================] - 0s 736us/sample - loss: 0.1197 - val_loss: 0.1277
# Epoch 50/200
# 81/81 [==============================] - 0s 645us/sample - loss: 0.1189 - val_loss: 0.1256
# Epoch 51/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1186 - val_loss: 0.1246
# Epoch 52/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1186 - val_loss: 0.1246
# Epoch 53/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1184 - val_loss: 0.1255
# Epoch 54/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1181 - val_loss: 0.1263
# Epoch 55/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1183 - val_loss: 0.1265
# Epoch 56/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1180 - val_loss: 0.1253
# Epoch 57/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1174 - val_loss: 0.1267
# Epoch 58/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1179 - val_loss: 0.1262
# Epoch 59/200
# 81/81 [==============================] - 0s 601us/sample - loss: 0.1181 - val_loss: 0.1242
# Epoch 60/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1173 - val_loss: 0.1259
# Epoch 61/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1180 - val_loss: 0.1268
# Epoch 62/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1163 - val_loss: 0.1232
# Epoch 63/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1183 - val_loss: 0.1224
# Epoch 64/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1173 - val_loss: 0.1278
# Epoch 65/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1174 - val_loss: 0.1261
# Epoch 66/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1162 - val_loss: 0.1254
# Epoch 67/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1159 - val_loss: 0.1267
# Epoch 68/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1160 - val_loss: 0.1261
# Epoch 69/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1156 - val_loss: 0.1253
# Epoch 70/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1154 - val_loss: 0.1222
# Epoch 71/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1157 - val_loss: 0.1241
# Epoch 72/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1151 - val_loss: 0.1253
# Epoch 73/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1152 - val_loss: 0.1245
# Epoch 74/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1150 - val_loss: 0.1234
# Epoch 75/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1160 - val_loss: 0.1230
# Epoch 76/200
# 81/81 [==============================] - 0s 668us/sample - loss: 0.1149 - val_loss: 0.1311
# Epoch 77/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1171 - val_loss: 0.1342
# Epoch 78/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1164 - val_loss: 0.1286
# Epoch 79/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1148 - val_loss: 0.1257
# Epoch 80/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1156 - val_loss: 0.1221
# Epoch 81/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1142 - val_loss: 0.1259
# Epoch 82/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1151 - val_loss: 0.1237
# Epoch 83/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1155 - val_loss: 0.1255
# Epoch 84/200
# 81/81 [==============================] - ETA: 0s - loss: 0.112 - 0s 691us/sample - loss: 0.1140 - val_loss: 0.1296
# Epoch 85/200
# 81/81 [==============================] - 0s 592us/sample - loss: 0.1148 - val_loss: 0.1289
# Epoch 86/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1141 - val_loss: 0.1245
# Epoch 87/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1134 - val_loss: 0.1234
# Epoch 88/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1139 - val_loss: 0.1242
# Epoch 89/200
# 81/81 [==============================] - 0s 710us/sample - loss: 0.1137 - val_loss: 0.1268
# Epoch 90/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1141 - val_loss: 0.1254
# Epoch 91/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1132 - val_loss: 0.1250
# Epoch 92/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1130 - val_loss: 0.1266
# Epoch 93/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1144 - val_loss: 0.1295
# Epoch 94/200
# 81/81 [==============================] - 0s 622us/sample - loss: 0.1133 - val_loss: 0.1251
# Epoch 95/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1141 - val_loss: 0.1251
# Epoch 96/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1135 - val_loss: 0.1287
# Epoch 97/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1138 - val_loss: 0.1258
# Epoch 98/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1125 - val_loss: 0.1241
# Epoch 99/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1123 - val_loss: 0.1246
# Epoch 100/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1131 - val_loss: 0.1263
# Epoch 101/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1123 - val_loss: 0.1244
# Epoch 102/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1123 - val_loss: 0.1249
# Epoch 103/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1121 - val_loss: 0.1261
# Epoch 104/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1132 - val_loss: 0.1253
# Epoch 105/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1125 - val_loss: 0.1254
# Epoch 106/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1132 - val_loss: 0.1291
# Epoch 107/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1123 - val_loss: 0.1265
# Epoch 108/200
# 81/81 [==============================] - 0s 736us/sample - loss: 0.1114 - val_loss: 0.1261
# Epoch 109/200
# 81/81 [==============================] - 0s 595us/sample - loss: 0.1123 - val_loss: 0.1270
# Epoch 110/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1114 - val_loss: 0.1274
# Epoch 111/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1120 - val_loss: 0.1265
# Epoch 112/200
# 81/81 [==============================] - 0s 651us/sample - loss: 0.1116 - val_loss: 0.1257
# Epoch 113/200
# 81/81 [==============================] - 0s 544us/sample - loss: 0.1116 - val_loss: 0.1266
# Epoch 114/200
# 81/81 [==============================] - 0s 583us/sample - loss: 0.1113 - val_loss: 0.1256
# Epoch 115/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1116 - val_loss: 0.1258
# Epoch 116/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1117 - val_loss: 0.1263
# Epoch 117/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1109 - val_loss: 0.1267
# Epoch 118/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1109 - val_loss: 0.1269
# Epoch 119/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1119 - val_loss: 0.1275
# Epoch 120/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1113 - val_loss: 0.1246
# Epoch 121/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1108 - val_loss: 0.1242
# Epoch 122/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1111 - val_loss: 0.1238
# Epoch 123/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1112 - val_loss: 0.1245
# Epoch 124/200
# 81/81 [==============================] - 0s 828us/sample - loss: 0.1105 - val_loss: 0.1272
# Epoch 125/200
# 81/81 [==============================] - 0s 607us/sample - loss: 0.1107 - val_loss: 0.1287
# Epoch 126/200
# 81/81 [==============================] - 0s 695us/sample - loss: 0.1111 - val_loss: 0.1267
# Epoch 127/200
# 81/81 [==============================] - 0s 591us/sample - loss: 0.1104 - val_loss: 0.1249
# Epoch 128/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1106 - val_loss: 0.1256
# Epoch 129/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1111 - val_loss: 0.1256
# Epoch 130/200
# 81/81 [==============================] - 0s 618us/sample - loss: 0.1105 - val_loss: 0.1276
# Epoch 131/200
# 81/81 [==============================] - 0s 695us/sample - loss: 0.1111 - val_loss: 0.1281
# Epoch 132/200
# 81/81 [==============================] - 0s 717us/sample - loss: 0.1106 - val_loss: 0.1249
# Epoch 133/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1100 - val_loss: 0.1246
# Epoch 134/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1099 - val_loss: 0.1251
# Epoch 135/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1101 - val_loss: 0.1264
# Epoch 136/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1104 - val_loss: 0.1267
# Epoch 137/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1097 - val_loss: 0.1266
# Epoch 138/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1103 - val_loss: 0.1273
# Epoch 139/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1102 - val_loss: 0.1268
# Epoch 140/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1103 - val_loss: 0.1244
# Epoch 141/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1105 - val_loss: 0.1257
# Epoch 142/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1110 - val_loss: 0.1357
# Epoch 143/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1120 - val_loss: 0.1288
# Epoch 144/200
# 81/81 [==============================] - 0s 763us/sample - loss: 0.1103 - val_loss: 0.1285
# Epoch 145/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1107 - val_loss: 0.1259
# Epoch 146/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1105 - val_loss: 0.1260
# Epoch 147/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1104 - val_loss: 0.1238
# Epoch 148/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1091 - val_loss: 0.1261
# Epoch 149/200
# 81/81 [==============================] - 0s 695us/sample - loss: 0.1095 - val_loss: 0.1281
# Epoch 150/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1091 - val_loss: 0.1248
# Epoch 151/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1093 - val_loss: 0.1242
# Epoch 152/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1097 - val_loss: 0.1243
# Epoch 153/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1093 - val_loss: 0.1280
# Epoch 154/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1087 - val_loss: 0.1273
# Epoch 155/200
# 81/81 [==============================] - 0s 447us/sample - loss: 0.1087 - val_loss: 0.1253
# Epoch 156/200
# 81/81 [==============================] - 0s 786us/sample - loss: 0.1086 - val_loss: 0.1248
# Epoch 157/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1083 - val_loss: 0.1264
# Epoch 158/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1084 - val_loss: 0.1277
# Epoch 159/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1087 - val_loss: 0.1283
# Epoch 160/200
# 81/81 [==============================] - 0s 622us/sample - loss: 0.1074 - val_loss: 0.1263
# Epoch 161/200
# 81/81 [==============================] - 0s 698us/sample - loss: 0.1096 - val_loss: 0.1242
# Epoch 162/200
# 81/81 [==============================] - 0s 695us/sample - loss: 0.1095 - val_loss: 0.1260
# Epoch 163/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1098 - val_loss: 0.1249
# Epoch 164/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1080 - val_loss: 0.1252
# Epoch 165/200
# 81/81 [==============================] - 0s 759us/sample - loss: 0.1079 - val_loss: 0.1258
# Epoch 166/200
# 81/81 [==============================] - 0s 718us/sample - loss: 0.1074 - val_loss: 0.1310
# Epoch 167/200
# 81/81 [==============================] - 0s 703us/sample - loss: 0.1085 - val_loss: 0.1261
# Epoch 168/200
# 81/81 [==============================] - 0s 741us/sample - loss: 0.1066 - val_loss: 0.1254
# Epoch 169/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1071 - val_loss: 0.1257
# Epoch 170/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1076 - val_loss: 0.1261
# Epoch 171/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1070 - val_loss: 0.1261
# Epoch 172/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1065 - val_loss: 0.1246
# Epoch 173/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1069 - val_loss: 0.1253
# Epoch 174/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1060 - val_loss: 0.1265
# Epoch 175/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1062 - val_loss: 0.1259
# Epoch 176/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1063 - val_loss: 0.1256
# Epoch 177/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1055 - val_loss: 0.1262
# Epoch 178/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1052 - val_loss: 0.1267
# Epoch 179/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1105 - val_loss: 0.1259
# Epoch 180/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1061 - val_loss: 0.1343
# Epoch 181/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1081 - val_loss: 0.1265
# Epoch 182/200
# 81/81 [==============================] - 0s 684us/sample - loss: 0.1065 - val_loss: 0.1233
# Epoch 183/200
# 81/81 [==============================] - 0s 801us/sample - loss: 0.1053 - val_loss: 0.1395
# Epoch 184/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1091 - val_loss: 0.1287
# Epoch 185/200
# 81/81 [==============================] - 0s 839us/sample - loss: 0.1071 - val_loss: 0.1248
# Epoch 186/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1039 - val_loss: 0.1322
# Epoch 187/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1068 - val_loss: 0.1294
# Epoch 188/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1049 - val_loss: 0.1250
# Epoch 189/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1028 - val_loss: 0.1280
# Epoch 190/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1033 - val_loss: 0.1352
# Epoch 191/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1058 - val_loss: 0.1262
# Epoch 192/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1014 - val_loss: 0.1262
# Epoch 193/200
# 81/81 [==============================] - 0s 735us/sample - loss: 0.1022 - val_loss: 0.1313
# Epoch 194/200
# 81/81 [==============================] - 0s 716us/sample - loss: 0.1035 - val_loss: 0.1276
# Epoch 195/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.1034 - val_loss: 0.1224
# Epoch 196/200
# 81/81 [==============================] - 0s 691us/sample - loss: 0.0998 - val_loss: 0.1389
# Epoch 197/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1035 - val_loss: 0.1274
# Epoch 198/200
# 81/81 [==============================] - 0s 790us/sample - loss: 0.1003 - val_loss: 0.1235
# Epoch 199/200
# 81/81 [==============================] - 0s 698us/sample - loss: 0.1004 - val_loss: 0.1271
# Epoch 200/200
# 81/81 [==============================] - 0s 593us/sample - loss: 0.1001 - val_loss: 0.1225
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 8, 20)             2480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8, 20)             3280
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 10)                1240
# _________________________________________________________________
# dense (Dense)                (None, 2)                 22
# =================================================================
# Total params: 7,022
# Trainable params: 7,022
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### preprocess the whole data

# %%
#i: index location of last point in training
#forecast_iterations: number of iterations to be the forecast loop will run. 
#Forecast points= output_length* forecast_iterations

def forecast(df_complete, i, forecast_iterations ):

    
    #scale the dataframe 
    df_complete_updated = df_complete*scaler.scale_
    #iterate till we have all required number of forecast points

    for iter in range(0,forecast_iterations):
        # for each iteration
        #1  Extract the model input
        temp= df_complete_updated[(df_complete_updated.index<= df_complete_updated.index[i]).astype(bool) & (df_complete_updated.index> df_complete_updated.index[i-train_length]).astype(bool)]
        #2  turn datframe into array and Shape it as required bythe model
        model_input= temp.values.reshape(1,train_length,df_complete.shape[1])

        #validate that correct transformation has been done

        model_input[0,:,0] # shows predictor variable latest 8 values in a scaled format
        #3) Pass it to the model and forecast the output
        model_output= model.predict(model_input)
        
        
        #4) update the values in the dataframe with the forecasted values
        
        df_complete_updated.loc[
                    df_complete_updated.index[i+1:i+1+output_length]

            ,forecast_variable]= model_output
        
        #5) Update the index- index location of the last observation of model input array
        i= i+output_length
    
    #inverse transform scaling to obtain original values. This is done at once after all iterations have been done.
    df_complete_updated= df_complete_updated/ scaler.scale_
    
    return df_complete_updated

# %% [markdown]
# #### Prepare data to validate on the test set

# %%
i= 110
forecast_iterations =int(n_test/output_length) # 8/4
import tensorflow as tf

df_complete_updated_test= forecast(df_complete, i, forecast_iterations)

# %% [markdown]
# #### Prepare data to forecast on the complete set

# %%
i= 118
forecast_iterations =int(forecast_points/output_length)# 40/4

df_complete_updated_forecast= forecast(df_complete, i, forecast_iterations)

# %% [markdown]
# #### Combine all three data for plotting purpose

# %%
import numpy as np

plot_data= pd.concat([
           df_complete_updated_test[forecast_variable],
           df_complete_updated_forecast[forecast_variable],
            df_complete[forecast_variable]], axis=1)
plot_data.columns= ['test','predicted', 'actual']
type(plot_data.predicted[-1])
plot_data.loc[plot_data.index<='2017Q3','test']=np.nan
plot_data.loc[plot_data.index>'2019Q3','test']=np.nan

plot_data.loc[plot_data.index<='2019Q3','predicted']=np.nan

# %% [markdown]
# #### Comparison of accuracy on test set

# %%
plot_data[['actual', 'test']][111:119].plot()
plt.title('comparison of last 2 years output with actual')
# Out:
# Text(0.5, 1.0, 'comparison of last 2 years output with actual')

# %% [markdown]
# #### Computing performance and storing it in a file

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np 
from math import sqrt
print("MAE")
mae= mean_absolute_error(plot_data[111:119].actual.values, plot_data[111:119].test.values)
print(mae)
print("RSME")
rmse= sqrt(mean_squared_error(plot_data[111:119].actual.values, plot_data[111:119].test.values))
print(rmse)
# Out:
# MAE
# 237.95449803796566
# RSME
# 264.8979275788432

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from numpy import math
metrics= pd.read_csv('E:/Python WD/time_series/data/metrics.csv', index_col='Unnamed: 0')
metrics.loc['mean absolute error', 'lstm']= mae
print('mean absolute error: '+str(mae))
metrics.loc['mean squared error', 'lstm']= rmse
print('root mean squared error: '+str(rmse))

metrics.to_csv('E:/Python WD/time_series/data/metrics.csv')
#metrics
# Out:
# mean absolute error: 237.95449803796566
# root mean squared error: 264.8979275788432

# %% [markdown]
# #### Forecast for next 10 years

# %%
plot_data[['actual','predicted']].plot()
plt.title('forecast of next 10 years data')
# Out:
# Text(0.5, 1.0, 'forecast of next 10 years data')

# %% [markdown]
# #### Storing the forecasts for next 10 years

# %%
predictions= pd.read_csv('E:/Python WD/time_series/data/predictions.csv', index_col= 'Unnamed: 0')
#obtain predictions for next 10 years
temp= plot_data[plot_data.index>'2019Q3'][['predicted']][0:40]
predictions.loc[:,'lstm']=temp.values
predictions.to_csv('E:/Python WD/time_series/data/predictions.csv')
